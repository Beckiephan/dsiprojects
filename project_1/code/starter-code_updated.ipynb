# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# As the new format for the SAT was released in March 2016, the College Board wants to track the statewide participation to analyze in which states require more budget in order to increase the SAT participation rates and tracking the scores by participants would allow us to evaluate and find out how are the participants performing with the change in format of the SAT.
#
# We'll seek to identify trends in the data and combine our data analysis with outside research to identify likely factors influencing participation rates and scores in various states

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Sources](#Sources)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:

act_2017 = pd.read_csv('/Users/becksphan/Desktop/DSI-18Workarea/classes/Project1234/project_1/data/act_2017.csv')
sat_2017 = pd.read_csv('/Users/becksphan/Desktop/DSI-18Workarea/classes/Project1234/project_1/data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
act_2017.shape
# Out:
# (52, 7)

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
round(sat_2017.describe())
# Out:
#        Evidence-Based Reading and Writing   Math   Total
# count                                51.0   51.0    51.0
# mean                                569.0  548.0  1126.0
# std                                  46.0   85.0    92.0
# min                                 482.0   52.0   950.0
# 25%                                 534.0  522.0  1056.0
# 50%                                 559.0  548.0  1107.0
# 75%                                 613.0  599.0  1212.0
# max                                 644.0  651.0  1295.0

# %%
round(act_2017.describe())
# Out:
#        English  Math  Reading  Science
# count     52.0  52.0     52.0     52.0
# mean      21.0  21.0     22.0     21.0
# std        2.0   2.0      2.0      3.0
# min       16.0  18.0     18.0      2.0
# 25%       19.0  19.0     20.0     20.0
# 50%       21.0  21.0     22.0     21.0
# 75%       23.0  23.0     24.0     23.0
# max       26.0  25.0     26.0     25.0

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.shape
# Out:
# (52, 7)

# %% [markdown]
# The data shows the 2017 participation rate and the scores for each subject for both SAT and ACT in different States in the United States. For SAT, the scores consist of Evidence-Based Reading and Writing(ERW), Math and shows the Total score of both combined. Whereas for ACT, the scores consist of English, Math, Reading, Science and the composite of the four subjects. There are a total of 51 rows in the sat_2017 data and 52 rows in act_2017 data.
#
# The .describe() function provides statistical data showing the mean, standard deviation, the min, the first quartile, the second quartile, the third quartile and the max value of the numerical record of each attribute.
#
# For the 2017 SAT data, the standard deviation for ERW is smaller than the Math, which means the score for ERW does not deviate away from the mean score of 569.12 as much as it does for Math with a mean score of 547.63. This is further explained as we see the min score of ERW being 482 whereas the min score for Math is 52, which is a large deviation from its mean.
#
# For the 2017 ACT data, the standard deviation for all its subjects are not high, meaning the scores for each subject in each state do not deviate too much from its respective means. This can be explained as ACT scoring system uses a scaling point system where it converts the raw scores to a scaled score between 1 to 36. Therefore as the scale range is small, the chances high deviation from the mean is low.

# %% [markdown]
# #### <u> Sources for the different scoring system and its score range
#
# Author’s name, ***Prep Zone Academy***. Title of Document, ***SHOULD I TAKE THE SAT OR ACT?***. Title of Website, ***Prep Zone Academy|SAT***. Sponsor of Website, ***Prep Zone Academy***. Date of Document, ***Year 2020***. Date of Access, ***November 3, 2020***. URL, https://sat.edu.sg/sat-vs-act/?utm_source=google&utm_medium=cpc&utm_campaign=SAT-generic&utm_keyword=sat%20and%20act&matchtype=p&device=c&adposition=&adgroupid=107972716251&gclid=EAIaIQobChMIs765vq7t7AIVgWkqCh1w6Qx3EAAYASAAEgIY0_D_BwE
#
# Author’s name, ***Halle Edwards***. Title of Document, ***SAT / ACT Prep Online Guides and Tips
# How Is the SAT Scored? Scoring Charts***. Title of Website, ***PrepScholar New SAT***. Sponsor of Website, ***SAT College board***. Date of Document, ***January 2, 2020***. Date of Access, ***November 3, 2020***. URL, https://blog.prepscholar.com/how-is-the-sat-scored-scoring-charts

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
sat_2017.nunique()
# Out:
# State                                 51
# Participation                         34
# Evidence-Based Reading and Writing    46
# Math                                  46
# Total                                 48
# dtype: int64

# %%
act_2017.nunique()
# Out:
# State            52
# Participation    28
# English          36
# Math             34
# Reading          39
# Science          35
# Composite        38
# dtype: int64

# %%
sat_2017.info() # to check if there are any null or missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# The data for both sat_2017 and act_2017 looks complete.
#
# There are 51 rows in sat_2017 data and from the .nunique() function, this is to ensure there are no duplicate States. Using the .info() function, we can see that there are 51 values in each attribute and there are no null values.
#
# Similarly, there are 52 rows in act_2017 data and from the .nunique() function, this is to ensure there are no duplicate States. However, with 52 states, there seems to be an additional state which we will look into it and rectify later on. Using the .info() function, we can see that there are 52 values in each attribute and there are no null values.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# The minimum value of math falls out of the range of the scores for SAT.

# %%
sat_2017.loc[sat_2017['Math']==52]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# Located that Maryland is the state with the incorrect data.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017.loc[act_2017['Science']==2.3]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %% [markdown]
# The min value for science seems too low and have located that this value is also for Maryland state.

# %% [markdown]
# ##### <u> Some obvious issues found

# %% [markdown]
# - The act_2017 data has a "national" state, which is not an actual State.
# - The composite for Wyoming in the act_2017 data is 20.2x which is not a correct value.
# - The SAT math min value of 52 falls out of the range of the scoring system for SAT. SAT scoring system is in the range of 200 to 800 for individual subjects and 400 to 1600 for the total. This value was located to be the average math score for the state of Maryland. Using the SAT link provided above, I have found that the score for math for the state of Maryland is suppose to be 524.
# - The science min value is 2.3 for ACT seems too low comparing to its mean and to the other scores. I have located that again Maryland state is the one with the lowest value of 2.3 for science and done a cross check of what the score is suppose to be. It turns out the score should be 23.2.

# %% [markdown]
# #### <u>Source of the 2017 ACT average scores
#
# Author’s name, ***Western Interstate
# Commission for Higher Education***. Title of Document, ***Average ACT Scores by State
#  Graduating Class 2017***. Title of Website, ***ACT***. Sponsor of Website, ***Knocking at the College Door - Projections of High
# School Graduates***. Date of Document, ***December 2016***. Date of Access, ***November 3, 2020***. URL, https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
#drop the row that has the "national" state
act_2017 = act_2017.drop(0)

# %%
act_2017.head(1)
# Out:
#      State Participation  English  Math  Reading  Science Composite
# 1  Alabama          100%     18.9  18.4     19.7     19.4      19.2

# %%
act_2017.shape #check that the National row has been dropped, indexed with 0
# Out:
# (51, 7)

# %%
#correcting the value of 20.2x composite score for Wyoming in act_2017 data
act_2017['Composite'] = act_2017['Composite'].replace('20.2x',20.2)
act_2017.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %%
#correcting the SAT average math value 52 from Maryland state to its correct value of 524.
sat_2017['Math'] = sat_2017['Math'].replace(52,524)
sat_2017.loc[sat_2017['State']== "Maryland"]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
#correcting the ACT average science value 2.3 from Maryland state to its correct value of 23.2.
act_2017['Science'] = act_2017['Science'].replace(2.3,23.2)
act_2017.loc[act_2017['State']== "Maryland"]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat_2017.info()
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   English        51 non-null     float64
#  3   Math           51 non-null     float64
# ...

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# - For both the SAT and ACT Participation, needs to be a float.
# - For ACT Composite needs to be a float as well.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#This is the apply function
#Removing the % sign to change the value to float

#def str_to_float(x):
#        x = float(x.replace('%',''))
#        return x

#apply this to sat_2017
#sat_2017['Participation'] = sat_2017['Participation'].apply(str_to_float)

# %%
# Using lambda to change participation rate to float type
sat_2017['Participation'] = sat_2017['Participation'].map(lambda x:float(x.replace('%','')))

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#Do the same for act_2017
act_2017['Participation'] = act_2017['Participation'].map(lambda x: float(x.replace('%','')))

# %%
# now change the composite values to be float using lambda
act_2017['Composite'] = act_2017['Composite'].map(lambda x:float(x))

# %%
#apply function method and defining the function first
#def str_to_float_2(x):
#    x = float(x)
#    return x

#apply this to the composite column which have str values to convert them to a float value
#act_2017['Composite'] = act_2017['Composite'].apply(str_to_float_2)

# %%
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %% [markdown]
# #code
# Fixed as seen above

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %% [markdown]
# #code
# As seen above

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
sat_2017.info()
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     float64
#  2   English        51 non-null     float64
# ...

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017.head(1)
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5.0                                 593   572   1165

# %%
act_2017.head(1)
# Out:
#      State  Participation  English  Math  Reading  Science  Composite
# 1  Alabama          100.0     18.9  18.4     19.7     19.4       19.2

# %%
#code, use .rename(columns={})

sat_2017.rename(columns={'State':'state',
                        'Participation':'sat17_par_percentage',
                        'Evidence-Based Reading and Writing':'sat17_erw',
                        'Math':'sat17_math',
                        'Total':'sat17_total'},inplace=True)
sat_2017.head(1)
# Out:
#      state  sat17_par_percentage  sat17_erw  sat17_math  sat17_total
# 0  Alabama                   5.0        593         572         1165

# %%
act_2017.rename(columns={'State':'state',
                        'Participation':'act17_par_percentage',
                        'English':'act17_english',
                        'Math':'act17_math',
                        'Reading':'act17_reading',
                        'Science':'act17_science',
                        'Composite':'act17_composite'},inplace=True)
act_2017.head(1)
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 1  Alabama                 100.0           18.9        18.4           19.7
#
#    act17_science  act17_composite
# 1           19.4             19.2

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# #### Data Dictionary for 2017

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|act_2017<br>sat_2017|The states in which the participation rates and scores are being recorded for.|
# |**act17_par_percentage**|*float*|act_2017|Average 2017 ACT percentage rate for each State.|
# |**act17_english**|*float*|act_2017|Average 2017 ACT English scaled score for each State.|
# |**act17_math**|*float*|act_2017|Average 2017 ACT Math scaled score for each State.|
# |**act17_reading**|*float*|act_2017|Average 2017 ACT scaled Reading score for each State.|
# |**act17_science**|*float*|act_2017|Average 2017 ACT scaled Science score for each State.|
# |**act17_composite**|*float*|act_2017|Average 2017 ACT scaled Composite score, which is the average of all individual subject score for each State.|
# |**sat17_par_percentage**|*float*|sat_2017|Average 2017 SAT percentage rate for each State.|
# |**sat17_erw**|*integer*|sat_2017|Average 2017 SAT English-based Reading and Writing score for each State.|
# |**sat17_math**|*integer*|sat_2017|Average 2017 SAT Math score for each State.|
# |**sat17_total**|*integer*|sat_2017|Average 2017 SAT total score for both subjects for each State.|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %% [markdown]
# Was reflected above dropping the row with state "National"

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code: Using the pd.merge function to merge all data(outer)
act_sat_17 = pd.merge(act_2017,sat_2017,on='state',how='outer')

act_sat_17.head(1)
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 0  Alabama                 100.0           18.9        18.4           19.7
#
#    act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 0           19.4             19.2                   5.0        593
#
#    sat17_math  sat17_total
# 0         572         1165

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
act_sat_17.to_csv('../data/combined_2017.csv',index=False)
combined_2017 = pd.read_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
act_2018 = pd.read_csv('../data/act_2018_updated.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')

# %%
sat_2018  #to check the full data at a glance
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
sat_2018.shape #ensure same rows as the 2017 data
# Out:
# (51, 5)

# %%
sat_2018['State'].nunique() #check if any duplicates
# Out:
# 51

# %%
sat_2018['State'].unique() #check there are no weird state
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Oklahoma', 'Ohio', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
sat_2018.describe() #check if there are any outliers
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# From the above description and info, it looks like all information is complete, the couple of things to change are the column names to differentiate them from the 2017 data and the Participation should be a float to be aligned with the 2017 data.

# %%
#Firstly, to change the participation to float type using lambda
sat_2018['Participation'] = sat_2018['Participation'].map(lambda x: float(x.replace("%","")))

# %%
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_2017.head(1) #for reference to rename columns
# Out:
#      state  sat17_par_percentage  sat17_erw  sat17_math  sat17_total
# 0  Alabama                   5.0        593         572         1165

# %%
#next is to rename all the columns to be distinct
sat_2018.rename(columns={'State':'state',
                        'Participation':'sat18_par_percentage',
                        'Evidence-Based Reading and Writing':'sat18_erw',
                        'Math':'sat18_math',
                        'Total':'sat18_total'},inplace=True)

# %%
sat_2018.head(1)
# Out:
#      state  sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 0  Alabama                   6.0        595         571         1166

# %%
#now we look at act_2018

# %%
act_2018 #just to look at the full data at a glance to spot any obvious issues
# Out:
#                    State  Percentage of Students Tested  \
# 0                Alabama                            100
# 1                 Alaska                             33
# 2                Arizona                             66
# 3               Arkansas                            100
# 4             California                             27
# 5               Colorado                             30
# 6            Connecticut                             26
# 7               Delaware                             17
# 8   District of Columbia                             32
# 9                Florida                             66
# 10               Georgia                             53
# 11                Hawaii                             89
# 12                 Idaho                             36
# 13              Illinois                             43
# 14               Indiana                             32
# 15                  Iowa                             68
# ...

# %%
act_2018.shape #similar rows with all the data above
# Out:
# (51, 7)

# %%
act_2018['State'].nunique() #no duplicates
# Out:
# 51

# %%
act_2018.describe()   #check if there are any outliers
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# ...

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# Similar to the sat_2018 data, there are not much issues with the data, only two things needs to change the data type of the percentage of students tested to float and rename the columns.

# %%
#First, to change the percentage to float.This is done by lambda function
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].map(lambda x: float(x))

# %%
act_2018.dtypes
# Out:
# State                             object
# Percentage of Students Tested    float64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
act_2017.head(1) #for reference to rename columns
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 1  Alabama                 100.0           18.9        18.4           19.7
#
#    act17_science  act17_composite
# 1           19.4             19.2

# %%
#Next, to rename the columns

act_2018.rename(columns= {'State':'state',
                        'Percentage of Students Tested': 'act18_par_percentage',
                         'Average Composite Score': 'act18_composite',
                         'Average English Score':'act18_english',
                         'Average Math Score':'act18_math',
                         'Average Reading Score':'act18_reading',
                         'Average Science Score':'act18_science'},inplace=True)

# %%
act_2018.head(1)
# Out:
#      state  act18_par_percentage  act18_composite  act18_english  act18_math  \
# 0  Alabama                 100.0             19.1           18.9        18.3
#
#    act18_reading  act18_science
# 0           19.6           19.0

# %%
act_sat_18 = pd.merge(act_2018,sat_2018,how='outer',on='state')
act_sat_18.to_csv('../data/combined_2018.csv',index=False) #index false to prevent creation of a new index

# %%
combined_2018 = pd.read_csv('../data/combined_2018.csv')

# %%
combined_2018.head(3)
# Out:
#      state  act18_par_percentage  act18_composite  act18_english  act18_math  \
# 0  Alabama                 100.0             19.1           18.9        18.3
# 1   Alaska                  33.0             20.8           19.8        20.6
# 2  Arizona                  66.0             19.2           18.2        19.4
#
#    act18_reading  act18_science  sat18_par_percentage  sat18_erw  sat18_math  \
# 0           19.6           19.0                   6.0        595         571
# 1           21.6           20.7                  43.0        562         544
# 2           19.5           19.2                  29.0        577         572
#
#    sat18_total
# 0         1166
# 1         1106
# 2         1149

# %% [markdown]
# #### Data Dictionary for 2018

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|act_2018<br>sat_2018|The states in which the 2018 ACT and SAT participation rates and scores are being recorded for.|
# |**act18_par_percentage**|*float*|act_2018|Average 2018 ACT percentage rate for each State.|
# |**act18_english**|*float*|act_2018|Average 2018 ACT English scaled score for each State.|
# |**act18_math**|*float*|act_2018|Average 2018 ACT Math scaled score for each State.|
# |**act18_reading**|*float*|act_2018|Average 2018 ACT scaled Reading score for each State.|
# |**act18_science**|*float*|act_2018|Average 2018 ACT scaled Science score for each State.|
# |**act18_composite**|*float*|act_2018|Average 2018 ACT scaled Composite score, which is the average of all individual subject score for each State.|
# |**sat18_par_percentage**|*float*|sat_2018|Average 2018 SAT percentage rate for each State.|
# |**sat18_erw**|*integer*|sat_2018|Average 2018 SAT English-based Reading and Writing score for each State.|
# |**sat18_math**|*integer*|sat_2018|Average 2018 SAT Math score for each State.|
# |**sat18_total**|*integer*|sat_2018|Average 2018 SAT total score for both subjects for each State.|

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#As we want to combine on state but include all data from 2018 and 2017 of both SAT and ACT, use outer and save it to final.csv

combine_2017_2018 = pd.merge(combined_2017,combined_2018, on='state', how='outer')
combine_2017_2018.to_csv('../data/final.csv',index=False)

#index=False means to use original index and not create a new one

# %%
combined_all = pd.read_csv('../data/final.csv')

# %%
combined_all.head()
# Out:
#         state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 0     Alabama                 100.0           18.9        18.4           19.7
# 1      Alaska                  65.0           18.7        19.8           20.4
# 2     Arizona                  62.0           18.6        19.8           20.1
# 3    Arkansas                 100.0           18.9        19.0           19.7
# 4  California                  31.0           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 0           19.4             19.2                   5.0        593
# 1           19.9             19.8                  38.0        547
# 2           19.8             19.7                  30.0        563
# 3           19.5             19.4                   3.0        614
# 4           22.2             22.8                  53.0        531
#
#    sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
combined_all.describe()
# Out:
#        act17_par_percentage  act17_english  act17_math  act17_reading  \
# count             51.000000      51.000000   51.000000      51.000000
# mean              65.254902      20.931373   21.182353      22.013725
# std               32.140842       2.353677    1.981989       2.067271
# min                8.000000      16.300000   18.000000      18.100000
# 25%               31.000000      19.000000   19.400000      20.450000
# 50%               69.000000      20.700000   20.900000      21.800000
# 75%              100.000000      23.300000   23.100000      24.150000
# max              100.000000      25.500000   25.300000      26.000000
#
#        act17_science  act17_composite  sat17_par_percentage   sat17_erw  \
# count      51.000000        51.000000             51.000000   51.000000
# mean       21.450980        21.519608             39.803922  569.117647
# std         1.739353         2.020695             35.276632   45.666901
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
combined_all.head()
# Out:
#         state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 0     Alabama                 100.0           18.9        18.4           19.7
# 1      Alaska                  65.0           18.7        19.8           20.4
# 2     Arizona                  62.0           18.6        19.8           20.1
# 3    Arkansas                 100.0           18.9        19.0           19.7
# 4  California                  31.0           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 0           19.4             19.2                   5.0        593
# 1           19.9             19.8                  38.0        547
# 2           19.8             19.7                  30.0        563
# 3           19.5             19.4                   3.0        614
# 4           22.2             22.8                  53.0        531
#
#    sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# ...

# %%
len(combined_all)
# Out:
# 51

# %%
#def variance(data, ddof=0):
 #   n = len(data)
  #  mean = sum(data) / n
   # return sum((x - mean) ** 2 for x in data) / (n - ddof)
#def stdev(data):
 #   var = variance(data)
  #  std_dev = math.sqrt(var)
   # return std_dev

# %%
#def standard_deviation(col):
#    sum_values = 0
 #   mean = final[col].mean()
  #  for value in final[col]:
        # Calculate sum of squared distance from each data point to the mean
   #     sum_values += (value - mean) ** 2
    # The index is counted as an extra row, hence len - 1
    #return (sum_values/(len(final[col]) - 1)) ** 0.5

# %%
def standard_dev(data):
    n = len(data)
    mean = sum(data)/n
    sd = (sum(((x - mean)**2) for x in data)/n)**0.5
    return sd

# %%
standard_dev(combined_all['act17_english'])
# Out:
# 2.3304876369363363

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
combined_all.columns
# Out:
# Index(['state', 'act17_par_percentage', 'act17_english', 'act17_math',
#        'act17_reading', 'act17_science', 'act17_composite',
#        'sat17_par_percentage', 'sat17_erw', 'sat17_math', 'sat17_total',
#        'act18_par_percentage', 'act18_composite', 'act18_english',
#        'act18_math', 'act18_reading', 'act18_science', 'sat18_par_percentage',
#        'sat18_erw', 'sat18_math', 'sat18_total'],
#       dtype='object')

# %%
new_combined_all = []
for x in combined_all.columns:
    if x != 'state':
        new_combined_all.append(x)

# %%
print(new_combined_all)
# Out:
# ['act17_par_percentage', 'act17_english', 'act17_math', 'act17_reading', 'act17_science', 'act17_composite', 'sat17_par_percentage', 'sat17_erw', 'sat17_math', 'sat17_total', 'act18_par_percentage', 'act18_composite', 'act18_english', 'act18_math', 'act18_reading', 'act18_science', 'sat18_par_percentage', 'sat18_erw', 'sat18_math', 'sat18_total']

# %%
#Code:

#for col in combined_all.columns:
 #   {col = standard_dev(combined_all[col])}

sd_dict = {col: (standard_dev(combined_all[col])) for col in new_combined_all}

# %%
sd_dict
# Out:
# {'act17_par_percentage': 31.824175751231806,
#  'act17_english': 2.3304876369363363,
#  'act17_math': 1.9624620273436781,
#  'act17_reading': 2.0469029314842646,
#  'act17_science': 1.7222161451443676,
#  'act17_composite': 2.000786081581989,
#  'sat17_par_percentage': 34.92907076664508,
#  'sat17_erw': 45.21697020437866,
#  'sat17_math': 46.65713364485503,
#  'sat17_total': 91.58351056778743,
#  'act18_par_percentage': 33.745194881997506,
#  'act18_composite': 2.0855261815801147,
#  'act18_english': 2.4222536143202795,
#  'act18_math': 2.015707255555717,
#  'act18_reading': 2.145891884510421,
#  'act18_science': 1.8516885484833543,
#  'sat18_par_percentage': 36.946619223539415,
#  'sat18_erw': 47.03460978357609,
#  'sat18_math': 47.30194550378352,
#  'sat18_total': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
np.std(combined_all)
# Out:
# act17_par_percentage    31.824176
# act17_english            2.330488
# act17_math               1.962462
# act17_reading            2.046903
# act17_science            1.722216
# act17_composite          2.000786
# sat17_par_percentage    34.929071
# sat17_erw               45.216970
# sat17_math              46.657134
# sat17_total             91.583511
# act18_par_percentage    33.745195
# act18_composite          2.085526
# act18_english            2.422254
# act18_math               2.015707
# act18_reading            2.145892
# act18_science            1.851689
# sat18_par_percentage    36.946619
# sat18_erw               47.034610
# sat18_math              47.301946
# sat18_total             93.227424
# dtype: float64

# %% [markdown]
# Answer: My manually calculated standard deviation does not match up with the output from pandas describe. However, it matached with numpy's std.

# %% [markdown]
# https://stackoverflow.com/questions/24984178/different-std-in-pandas-vs-numpy

# %%
np.std(combined_all,ddof=1) 
# to compare to above numpy's std, will be the same as pandas descirbe as it starts with the first row
# Out:
# act17_par_percentage    32.140842
# act17_english            2.353677
# act17_math               1.981989
# act17_reading            2.067271
# act17_science            1.739353
# act17_composite          2.020695
# sat17_par_percentage    35.276632
# sat17_erw               45.666901
# sat17_math              47.121395
# sat17_total             92.494812
# act18_par_percentage    34.080976
# act18_composite          2.106278
# act18_english            2.446356
# act18_math               2.035765
# act18_reading            2.167245
# act18_science            1.870114
# sat18_par_percentage    37.314256
# sat18_erw               47.502627
# sat18_math              47.772623
# sat18_total             94.155083
# dtype: float64

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#using sort function to find the state with the lowest participation rate for act 2017

combined_all[["state","act17_par_percentage"]].sort_values(by='act17_par_percentage',ascending=True).head(20)
# Out:
#                    state  act17_par_percentage
# 19                 Maine                   8.0
# 29         New Hampshire                  18.0
# 7               Delaware                  18.0
# 39          Rhode Island                  21.0
# 38          Pennsylvania                  23.0
# 20              Maryland                  28.0
# 45               Vermont                  29.0
# 21         Massachusetts                  29.0
# 22              Michigan                  29.0
# 46              Virginia                  29.0
# 47            Washington                  29.0
# 4             California                  31.0
# 32              New York                  31.0
# 6            Connecticut                  31.0
# 8   District of Columbia                  32.0
# 30            New Jersey                  34.0
# 14               Indiana                  35.0
# 12                 Idaho                  38.0
# 37                Oregon                  40.0
# ...

# %% [markdown]
# According to my findings, the bottom 20 states are seen in the table, of which, the lowest participation rate is 8% as seen in Maine for the 2017 ACT.

# %%
#using sort function to find the lowest participation rate for act 2018

combined_all[["state","act18_par_percentage"]].sort_values(by='act18_par_percentage',ascending=True).head(20)
# Out:
#                    state  act18_par_percentage
# 19                 Maine                   7.0
# 39          Rhode Island                  15.0
# 29         New Hampshire                  16.0
# 7               Delaware                  17.0
# 38          Pennsylvania                  20.0
# 22              Michigan                  22.0
# 47            Washington                  24.0
# 45               Vermont                  24.0
# 46              Virginia                  24.0
# 21         Massachusetts                  25.0
# 6            Connecticut                  26.0
# 4             California                  27.0
# 32              New York                  27.0
# 5               Colorado                  30.0
# 30            New Jersey                  31.0
# 20              Maryland                  31.0
# 14               Indiana                  32.0
# 8   District of Columbia                  32.0
# 1                 Alaska                  33.0
# ...

# %% [markdown]
# According to my findings, the bottom 20 states are seen in the table, of which, the lowest participation rate is 7% as seen in Maine for the 2017 ACT.

# %%
#using sort function to find the state with the highest participation rate for act 2017

combined_all[["state","act17_par_percentage"]].sort_values(by="act17_par_percentage",ascending=False).head(20)
# Out:
#              state  act17_par_percentage
# 0          Alabama                 100.0
# 17        Kentucky                 100.0
# 49       Wisconsin                 100.0
# 44            Utah                 100.0
# 42       Tennessee                 100.0
# 40  South Carolina                 100.0
# 36        Oklahoma                 100.0
# 33  North Carolina                 100.0
# 28          Nevada                 100.0
# 26         Montana                 100.0
# 24     Mississippi                 100.0
# 23       Minnesota                 100.0
# 18       Louisiana                 100.0
# 25        Missouri                 100.0
# 50         Wyoming                 100.0
# 5         Colorado                 100.0
# 3         Arkansas                 100.0
# 34    North Dakota                  98.0
# 13        Illinois                  93.0
# 11          Hawaii                  90.0

# %% [markdown]
# According to my findings, the top 20 states are seen in the table, of which, the highest participation rate of 100% are seen in most of the states in the top 20 as seen above for the 2018 ACT.

# %%
#using sort function to find the highest participation rate for act 2018

combined_all[["state","act18_par_percentage"]].sort_values(by='act18_par_percentage',ascending=False).head(20)
# Out:
#              state  act18_par_percentage
# 0          Alabama                 100.0
# 17        Kentucky                 100.0
# 49       Wisconsin                 100.0
# 44            Utah                 100.0
# 42       Tennessee                 100.0
# 40  South Carolina                 100.0
# 36        Oklahoma                 100.0
# 35            Ohio                 100.0
# 33  North Carolina                 100.0
# 28          Nevada                 100.0
# 27        Nebraska                 100.0
# 26         Montana                 100.0
# 24     Mississippi                 100.0
# 18       Louisiana                 100.0
# 25        Missouri                 100.0
# 50         Wyoming                 100.0
# 3         Arkansas                 100.0
# 23       Minnesota                  99.0
# 34    North Dakota                  98.0
# 11          Hawaii                  89.0

# %% [markdown]
# According to my findings, the top 20 states are seen in the table, of which, the highest participation rate of 100% are seen in most of the states in the top 20 as seen above for the 2018 ACT.

# %%
#using sort function to find the state with the lowest participation rate for sat 2017

combined_all[["state","sat17_par_percentage"]].sort_values(by="sat17_par_percentage",ascending=True).head(20)
# Out:
#            state  sat17_par_percentage
# 34  North Dakota                   2.0
# 24   Mississippi                   2.0
# 15          Iowa                   2.0
# 25      Missouri                   3.0
# 44          Utah                   3.0
# 41  South Dakota                   3.0
# 27      Nebraska                   3.0
# 49     Wisconsin                   3.0
# 23     Minnesota                   3.0
# 50       Wyoming                   3.0
# 3       Arkansas                   3.0
# 16        Kansas                   4.0
# 17      Kentucky                   4.0
# 18     Louisiana                   4.0
# 0        Alabama                   5.0
# 42     Tennessee                   5.0
# 36      Oklahoma                   7.0
# 13      Illinois                   9.0
# 26       Montana                  10.0
# 5       Colorado                  11.0

# %% [markdown]
# According to my findings, the bottom 20 states are seen in the table, of which, the lowest participation rate of 2% are seen in 3 states, North Dakota, Mississippi and Iowa for the 2018 SAT.

# %%
#using sort function to find the state with the lowest participation rate for sat 2018

combined_all[["state","sat18_par_percentage"]].sort_values(by="sat18_par_percentage",ascending=True).head(20)
# Out:
#            state  sat18_par_percentage
# 34  North Dakota                   2.0
# 50       Wyoming                   3.0
# 41  South Dakota                   3.0
# 27      Nebraska                   3.0
# 49     Wisconsin                   3.0
# 24   Mississippi                   3.0
# 15          Iowa                   3.0
# 44          Utah                   4.0
# 23     Minnesota                   4.0
# 18     Louisiana                   4.0
# 17      Kentucky                   4.0
# 16        Kansas                   4.0
# 25      Missouri                   4.0
# 3       Arkansas                   5.0
# 0        Alabama                   6.0
# 42     Tennessee                   6.0
# 36      Oklahoma                   8.0
# 26       Montana                  10.0
# 31    New Mexico                  16.0
# 35          Ohio                  18.0

# %% [markdown]
# According to my findings, the bottom 20 states are seen in the table, of which, the state with the lowest participation rate of 2% is North Dakota for the 2018 SAT.

# %%
#using sort function to find the highest participation rate for sat 2017

combined_all[["state","sat17_par_percentage"]].sort_values(by='sat17_par_percentage',ascending=False).head(20)
# Out:
#                    state  sat17_par_percentage
# 8   District of Columbia                 100.0
# 22              Michigan                 100.0
# 6            Connecticut                 100.0
# 7               Delaware                 100.0
# 29         New Hampshire                  96.0
# 19                 Maine                  95.0
# 12                 Idaho                  93.0
# 9                Florida                  83.0
# 21         Massachusetts                  76.0
# 39          Rhode Island                  71.0
# 30            New Jersey                  70.0
# 20              Maryland                  69.0
# 32              New York                  67.0
# 46              Virginia                  65.0
# 38          Pennsylvania                  65.0
# 47            Washington                  64.0
# 14               Indiana                  63.0
# 43                 Texas                  62.0
# 10               Georgia                  61.0
# ...

# %% [markdown]
# According to my findings, the top 20 states are seen in the table, of which, the highest participation rate of 100% are seen in 4 states as shown in the table above for the 2017 SAT.

# %%
#using sort function to find the highest participation rate for sat 2018

combined_all[["state","sat18_par_percentage"]].sort_values(by="sat18_par_percentage",ascending=False).head(20)
# Out:
#                    state  sat18_par_percentage
# 5               Colorado                 100.0
# 6            Connecticut                 100.0
# 7               Delaware                 100.0
# 22              Michigan                 100.0
# 12                 Idaho                 100.0
# 19                 Maine                  99.0
# 13              Illinois                  99.0
# 39          Rhode Island                  97.0
# 29         New Hampshire                  96.0
# 8   District of Columbia                  92.0
# 30            New Jersey                  82.0
# 21         Massachusetts                  80.0
# 32              New York                  79.0
# 20              Maryland                  76.0
# 38          Pennsylvania                  70.0
# 10               Georgia                  70.0
# 47            Washington                  69.0
# 46              Virginia                  68.0
# 43                 Texas                  66.0
# ...

# %% [markdown]
# According to my findings, the top 20 states are seen in the table, of which, the highest participation rate of 100% are seen in 5 states as shown in the table above for the 2018 SAT.

# %%
#Find the states with the lowest mean composite score for ACT 2017 and 2018
combined_all[["state","act17_composite"]].sort_values(by="act17_composite",ascending=True).head(2)
# Out:
#           state  act17_composite
# 28       Nevada             17.8
# 24  Mississippi             18.6

# %%
combined_all[["state","act18_composite"]].sort_values(by="act18_composite",ascending=True).head(2)
# Out:
#              state  act18_composite
# 28          Nevada             17.7
# 40  South Carolina             18.3

# %% [markdown]
# From my findings, the lowest mean composite score for ACT in 2017 and 2018 is 17.8 and 17.7 respectively, both in the state of Nevada.

# %%
#Find the states with the highest mean composite score for ACT 2017 and 2018
combined_all[["state","act17_composite"]].sort_values(by="act17_composite",ascending=False).head(2)
# Out:
#             state  act17_composite
# 29  New Hampshire             25.5
# 21  Massachusetts             25.4

# %%
combined_all[["state","act18_composite"]].sort_values(by="act18_composite",ascending=False).head(2)
# Out:
#             state  act18_composite
# 6     Connecticut             25.6
# 21  Massachusetts             25.5

# %% [markdown]
# From my findings, the highest mean composite score for ACT in 2017 is 25.5 in New Hampshire whereas in 2018, the highest mean composite score of 25.5 was in Connecticut.

# %%
#Find the states with the lowest mean total score for SAT 2017 and 2018
combined_all[["state","sat17_total"]].sort_values(by="sat17_total",ascending=True).head(2)
# Out:
#                   state  sat17_total
# 8  District of Columbia          950
# 7              Delaware          996

# %%
combined_all[["state","sat18_total"]].sort_values(by="sat18_total",ascending=True).head(2)
# Out:
#                   state  sat18_total
# 8  District of Columbia          977
# 7              Delaware          998

# %% [markdown]
# From my findings, the lowest mean total score for SAT in 2017 and 2018 was 950 and 977 respectively, both in the District of Columbia.

# %%
#Find the states with the highest mean total score for SAT 2017 and 2018
combined_all[["state","sat17_total"]].sort_values(by="sat17_total",ascending=False).head(2)
# Out:
#         state  sat17_total
# 23  Minnesota         1295
# 49  Wisconsin         1291

# %%
combined_all[["state","sat18_total"]].sort_values(by="sat18_total",ascending=False).head(2)
# Out:
#         state  sat18_total
# 23  Minnesota         1298
# 49  Wisconsin         1294

# %% [markdown]
# From my findings, the highest mean total score for SAT in 2017 and 2018 was 1295 and 1298 respectively, both in Minnesota.

# %%
combined_all.loc[combined_all['act17_par_percentage']> 50].sort_values(by="act17_par_percentage")
# Out:
#              state  act17_par_percentage  act17_english  act17_math  \
# 10         Georgia                  55.0           21.0        20.9
# 2          Arizona                  62.0           18.6        19.8
# 1           Alaska                  65.0           18.7        19.8
# 31      New Mexico                  66.0           18.6        19.4
# 15            Iowa                  67.0           21.2        21.3
# 48   West Virginia                  69.0           20.0        19.4
# 9          Florida                  73.0           19.0        19.4
# 16          Kansas                  73.0           21.1        21.3
# 35            Ohio                  75.0           21.2        21.6
# 41    South Dakota                  80.0           20.7        21.5
# 27        Nebraska                  84.0           20.9        20.9
# 11          Hawaii                  90.0           17.8        19.2
# 13        Illinois                  93.0           21.0        21.2
# ...

# %%
combined_all.loc[combined_all['act18_par_percentage']> 50].sort_values(by="act18_par_percentage")
# Out:
#              state  act17_par_percentage  act17_english  act17_math  \
# 10         Georgia                  55.0           21.0        20.9
# 48   West Virginia                  69.0           20.0        19.4
# 2          Arizona                  62.0           18.6        19.8
# 9          Florida                  73.0           19.0        19.4
# 31      New Mexico                  66.0           18.6        19.4
# 15            Iowa                  67.0           21.2        21.3
# 16          Kansas                  73.0           21.1        21.3
# 41    South Dakota                  80.0           20.7        21.5
# 11          Hawaii                  90.0           17.8        19.2
# 34    North Dakota                  98.0           19.0        20.4
# 23       Minnesota                 100.0           20.4        21.5
# 35            Ohio                  75.0           21.2        21.6
# 36        Oklahoma                 100.0           18.5        18.8
# ...

# %% [markdown]
# From the data, we could see that Georgia, Florida and Hawaii are the 3 states that had more than 50% participation rate for both test in both years.

# %% [markdown]
# What was interesting is that Colorado had a shift from ACT participation rate of 100% to a 100% shift in SAT in 2018, and the ACT participation rate decreased drastically by 70% for ACT. Another interesting point is that the lowest participation rate for 2017 and 2018 are for the same states in both years. The highest participation rate can also be seen in the same few states as seen in the table below in both 2017 and 2018.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %% [markdown]
# ## Overview of the correlation between 2017 and 2018 ACT and SAT Participation rates and Test Scores using Heatmap

# %%
mask = np.triu(combined_all.corr())

# %%
plt.figure(figsize=(11,11))
sns.heatmap(combined_all.corr(),annot=True,fmt='.1g',square=True,mask=mask);
plt.title("2017 and 2018 Participation rates and Scores for ACT and SAT",fontsize= 16);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
sns.set_style("whitegrid")  #set a style for my following plots

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize=(18,12)) # You'll want to specify your figsize
    fig.suptitle("Comparison of 2017 and 2018 ACT and SAT",fontsize=20)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],bins=10) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i],fontsize=15)
        ax[i].set_xlabel(list_of_xlabels[i],fontsize=12,c="darkblue")
        ax[i].axvline(x=dataframe[column].mean(),c='red',linestyle="dashed")
        ax[i].axvline(x=dataframe[column].median(),c='green')
        ax[i].set_ylabel("Frequency",fontsize=12,c="darkblue")

# %%
#ax and fig have different commands for plotting

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
combined_all.head(1) #Referencing header names
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 0  Alabama                 100.0           18.9        18.4           19.7
#
#    act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 0           19.4             19.2                   5.0        593
#
#    sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 0         572  ...                 100.0             19.1           18.9
#
#    act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 0        18.3           19.6           19.0                   6.0        595
#
#    sat18_math  sat18_total
# 0         571         1166
#
# [1 rows x 21 columns]

# %% [markdown]
# #### <u>Histogram for SAT and ACT Participation rates

# %%
columns_par = ["sat17_par_percentage","sat18_par_percentage","act17_par_percentage","act18_par_percentage"]
titles_par = ["SAT 2017 Participation","SAT 2018 Participation","ACT 2017 Participation","ACT 2018 Participation"]
x_labels_par = ["Participation Rate","Participation Rate","Participation Rate","Participation Rate"]

# %%
subplot_histograms(combined_all, columns_par, titles_par, x_labels_par)

# %% [markdown]
# #### <u>Histogram for SAT and ACT Math Scores

# %%
columns_math = ["sat17_math","sat18_math","act17_math","act18_math"]
titles_math = ["Math Scores SAT 2017","Math Scores SAT 2018","Math Scores ACT 2017","Math Scores ACT 2018"]
x_labels_math = ["Scores","Scores","Scores","Scores"]

# %%
subplot_histograms(combined_all, columns_math, titles_math, x_labels_math)

# %% [markdown]
# #### <u> Histogram for SAT and ACT Reading/Verbal Scores

# %%
columns_read = ["sat17_erw","sat18_erw","act17_reading","act18_reading"]
titles_read = ["English-based Reading and writing Scores SAT 2017","English-based Reading and writing Scores SAT 2018","Reading Scores ACT 2017","Reading Scores ACT 2018"]
x_labels_read = ["Scores","Scores","Scores","Scores"]

# %%
subplot_histograms(combined_all, columns_read, titles_read, x_labels_read)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def scatter_plot(xvar, yvar, title):
    plt.figure(figsize=(15,7))
    plt.title(title, fontsize=15)
    ax = sns.regplot(x=xvar, y=yvar, marker='+', color='black', line_kws={'color': 'green'}, scatter_kws = {'s':10})

# %% [markdown]
# #### <u> Scatter plot for SAT vs. ACT math scores for 2017

# %%
scatter_plot(combined_all['sat17_math'], combined_all['act17_math'], "2017 SAT vs. ACT Math Scores")

# %% [markdown]
# The correlation between the act and sat math scores in the year 2017 has a weak negative correlation of each state. From the linear regression, according to the best fit line, it looks like as the SAT 2017 math score increases, the act 2017 math score seems to be decreasing. However, according to the scoring system, this data may not show the best relation. We will look into detail how the scoring for each test differs later on.

# %% [markdown]
# #### <u>Scatter plot for SAT vs. ACT Reading scores for 2017

# %%
scatter_plot(combined_all['sat17_erw'], combined_all['act17_reading'], "2017 SAT vs. ACT Reading Scores")

# %% [markdown]
# The correlation between the act and sat reading scores in the year 2017 has a weak negative correlation of each state. From the linear regression, according to the best fit line, it looks like as the SAT 2017 english-based reading and writing score increases, the act 2017 reading score seems to be decreasing. However, similar to what we see between the math scores of SAT and ACT above, this data may not show the best relation and similarly we will look into detail how the scoring for each test differs later on.

# %% [markdown]
# #### <u> Scatter plot for SAT vs. ACT Total/Composite scores for 2017

# %%
scatter_plot(combined_all['sat17_total'], combined_all['act17_composite'], "2017 SAT Total vs. ACT Composite Scores")

# %% [markdown]
# Having seen in the graphs above that the 2017 individual scores between subjects of SAT and ACT have a very weak negative correlation, therefore we can also see that the Total SAT and the ACT Composite scores follow a similar trend with the individual scores.

# %% [markdown]
# #### <u> Scatter plot for SAT Total scores for 2017 vs 2018

# %%
scatter_plot(combined_all['sat17_total'], combined_all['sat18_total'], "2017 vs 2018 Total SAT scores")

# %% [markdown]
# The SAT total scores for 2017 and 2018 have a strong positive correlation. This shows that each year the total scores for SAT follows a similar trend. As the scores for 2017 increase, the scores in 2018 increases as well. From this we can see that the participants in 2018 scored similarly to 2017.

# %% [markdown]
# #### <u> Scatter plot for ACT Composite scores for 2017 vs 2018

# %%
scatter_plot(combined_all['act17_composite'], combined_all['act18_composite'], "2017 vs 2018 ACT Composite scores")

# %% [markdown]
# The ACT composite scores for 2017 and 2018 have an extremely strong positive correlation. This shows that each year the total scores for ACT follows a similar trend. As the scores for 2017 increase, the scores in 2018 increases as well. From this we can see that the number of participants in 2018 scored similarly to 2018.

# %% [markdown]
# #### <u> Scatter plot for SAT Total scores for 2017 vs 2018

# %%
scatter_plot(combined_all['sat17_total'], combined_all['sat18_total'], "2017 vs 2018 SAT Total scores")

# %% [markdown]
# The SAT total scores for 2017 and 2018 also have a very strong positive correlation. This shows that each year the total scores for ACT follows a similar trend. As the scores for 2017 increase, the scores in 2018 increases as well. From this we can see that the number of participants in 2018 scored similarly to 2018. The positive correlation may seem slightly weaker than the ACT composite scores between 2017 and 2018 may be due to the more scaled scoring system of the ACT, which ensures that scores do not differ too widely.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# #### <u> Boxplot for Participation rates for SAT and ACT in 2017 and 2018

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data=combined_all[["act17_par_percentage","act18_par_percentage","sat17_par_percentage","sat18_par_percentage"]], 
            orient='v',fliersize=10,linewidth=2,saturation=0.8,notch=False,whis=1.5);

# %% [markdown]
# In general overview it can be seen that the participation rates for ACT in both years are higher than the participation rates in SAT.
#
# We can also see that the median of the total participants of the ACT for both years fall somewhere right in the middle of the box at around 70% in 2017 and 65% in 2018 participation rate. Which means half of the states fall above 70% participation rates in 2017, whereas in 2018, half of the

# %% [markdown]
# #### <u> Boxplot for Math and English-based Reading and Writing for SAT in 2017 and 2018

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data=combined_all[["sat17_math","sat18_math","sat17_erw","sat18_erw"]], 
            orient='v',fliersize=10,linewidth=2,saturation=0.8,notch=False,whis=1.5);

# %% [markdown]
# Most states fall above the median mark in both math and erw scores for both year 2017 and 2018. From this we can say that most participants in most states score well in the SAT, we should see this trend for SAT total score as well.

# %% [markdown]
# #### <u> Boxplot for SAT Total score in 2017 and 2018

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data=combined_all[["sat17_total","sat18_total"]], 
            orient='h',fliersize=10,linewidth=2,saturation=0.8,notch=False,whis=1.5);

# %% [markdown]
# As mentioned earlier, we do see the same trend. Most states have their SAT total scores above the 50% mark which is the median. For 2017 and 2018 about and estimate of three quarters of the states have a total average score of more that around 1100.

# %% [markdown]
# #### <u> Boxplot for ACT individual subject scores in 2017 and 2018

# %%
plt.figure(figsize = (17,10))
sns.boxplot(data=combined_all[["act17_english","act18_english", "act17_math", "act18_math","act17_reading", "act18_reading", "act17_science","act18_science"]], 
            orient='h',fliersize=10,linewidth=2,saturation=0.8,notch=False,whis=1.5);

# %% [markdown]
# Seems like there was an improvement in english and slight improvement for math and reading whereas science seem to have worsen a little from 2017 to 2018. Reading seems to be the subject the constantly does better than the other subjects over both years. English subject has the widest IQR meaning to say the score differs the most amongst each state.

# %% [markdown]
# #### <u> Boxplot for ACT Composite scores in 2017 and 2018

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data=combined_all[["act17_composite","act18_composite"]], 
            orient='h',fliersize=10,linewidth=2,saturation=0.8,notch=False,whis=1.5);

# %% [markdown]
# Relatively similar overall performance from the states of the ACT from 2017 and 2018.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### <u>Scatter plots to show the relation between individual scores to the participation rates

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=combined_all['sat17_math'], y=combined_all['sat17_par_percentage'], ax=ax1);
sns.regplot(x=combined_all['sat17_erw'], y=combined_all['sat17_par_percentage'], ax=ax2);

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=combined_all['sat18_math'], y=combined_all['sat18_par_percentage'], ax=ax1);
sns.regplot(x=combined_all['sat18_erw'], y=combined_all['sat18_par_percentage'], ax=ax2);

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=combined_all['sat17_total'], y=combined_all['sat17_par_percentage'], ax=ax1);
sns.regplot(x=combined_all['sat18_total'], y=combined_all['sat18_par_percentage'], ax=ax2);

# %% [markdown]
# For SAT in both 2017 and 2018, we can see a negative correlation between the scores and the participation rates. As more people participate in the SAT, the average scores decreases.

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=combined_all['act17_math'], y=combined_all['act17_par_percentage'], ax=ax1);
sns.regplot(x=combined_all['act17_reading'], y=combined_all['act17_par_percentage'], ax=ax2);

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=combined_all['act18_math'], y=combined_all['act18_par_percentage'], ax=ax1);
sns.regplot(x=combined_all['act18_reading'], y=combined_all['act18_par_percentage'], ax=ax2);

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
sns.regplot(x=combined_all['act17_composite'], y=combined_all['act17_par_percentage'], ax=ax1);
sns.regplot(x=combined_all['act18_composite'], y=combined_all['act18_par_percentage'], ax=ax2);

# %% [markdown]
# For ACT in both 2017 and 2018, similarly we can see a negative correlation between the scores and the participation rates. As more people participate in the ACT, the average scores decreases.

# %% [markdown]
# **<u>Line graphs to show the relation between the ACT and SAT participation rates**

# %%
# : - dotted line, v - triangle_down
# r - red, b - blue
combined_all[['act17_par_percentage', 'sat17_par_percentage']].plot(figsize=(15,7), style={'act17_par_percentage': '-r', 'sat17_par_percentage': ':vb'});  #if you include : it will become joined lines eg :vb

# %% [markdown]
# In this trend, comparing the participation rate of act and sat in 2017, we can see that in the state where the particiaption for one is high, the other is low. This is because most colleges accept either of the exams, therefore taking one exam, it negates the need to take the other.

# %%
combined_all[['act18_par_percentage', 'sat18_par_percentage']].plot(figsize=(15,7), style={'act18_par_percentage': ':r', 'sat18_par_percentage': '-vb'});

# %% [markdown]
# Similarly, in 2018 we see the same trend mentioned above for the participation rates in both SAT and ACT.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# #### <u> Participation rates for ACT 2017 and 2018

# %%
combined_all[["act17_par_percentage","act18_par_percentage","sat17_par_percentage","sat18_par_percentage"]].describe()
# Out:
#        act17_par_percentage  act18_par_percentage  sat17_par_percentage  \
# count             51.000000             51.000000             51.000000
# mean              65.254902             61.647059             39.803922
# std               32.140842             34.080976             35.276632
# min                8.000000              7.000000              2.000000
# 25%               31.000000             28.500000              4.000000
# 50%               69.000000             66.000000             38.000000
# 75%              100.000000            100.000000             66.000000
# max              100.000000            100.000000            100.000000
#
#        sat18_par_percentage
# count             51.000000
# mean              45.745098
# std               37.314256
# min                2.000000
# 25%                4.500000
# 50%               52.000000
# 75%               77.500000
# max              100.000000

# %%
combined_all.loc[combined_all['act17_par_percentage']>65.26].shape
# Out:
# (28, 21)

# %%
combined_all.loc[combined_all['act18_par_percentage']>61.64].shape
# Out:
# (27, 21)

# %%
combined_all.loc[combined_all['sat17_par_percentage']>39.8].shape
# Out:
# (25, 21)

# %%
combined_all.loc[combined_all['sat18_par_percentage']>45.74].shape
# Out:
# (27, 21)

# %%
combined_all.loc[combined_all['sat18_par_percentage']==2]
# Out:
#            state  act17_par_percentage  act17_english  act17_math  \
# 34  North Dakota                  98.0           19.0        20.4
#
#     act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 34           20.5           20.6             20.3                   2.0
#
#     sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 34        635         621  ...                  98.0             20.3
#
#     act18_english  act18_math  act18_reading  act18_science  \
# 34           19.1        20.3           20.7           20.5
#
#     sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 34                   2.0        640         643         1283
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['sat17_par_percentage']==2]
# Out:
#            state  act17_par_percentage  act17_english  act17_math  \
# 15          Iowa                  67.0           21.2        21.3
# 24   Mississippi                 100.0           18.2        18.1
# 34  North Dakota                  98.0           19.0        20.4
#
#     act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 15           22.6           22.1             21.9                   2.0
# 24           18.8           18.8             18.6                   2.0
# 34           20.5           20.6             20.3                   2.0
#
#     sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 15        641         635  ...                  68.0             21.8
# 24        634         607  ...                 100.0             18.6
# 34        635         621  ...                  98.0             20.3
#
#     act18_english  act18_math  act18_reading  act18_science  \
# 15           21.0        21.2           22.5           22.0
# ...

# %% [markdown]
# For ACT 2017 particiaption rates, the mean is about 65% which shows that most states have high participation rates. As seen, 28 out of the 51 states have an average participation rate that is above the mean.
#
# This is further emphasized with a median of 69%, which means about half the states have participation rates of more than 69%. This can be seen as the 3rd quartile is consist of states with participation rates of 69% to 100% and the 4th quartile consist of states with all 100% participation rates.
#
# The ACT 2017 participation rates have a bimodal distribution, there are 2 peaks, meaning that most states fall within 2 ranges or participation rates, a lower range of about 25% to 35% and a higher range of 90% to 100%. As seen from the histogram, more states fall in the higher range of 90% to 100% which explains the higher mean and median.
#
# The spread of the participation rates of ACT 2017 is 92. This is a wide spread as the interval range from 0 to 100. This explains why the standard deviation is very high at about 32. This means that many states have participation rates that are far from the mean of the participation rates of all states and the participation rates fall on a wide range with some states having very low participation rates will others having very high participation rates.
#
# For ACT 2018 participation rates it follows the 2017 statistical trend, its mean is about 62% which shows that most states have high participation rates. As seen, 27 out of the 51 states have an average participation rate that is above the mean.
#
# This is again further emphasized with a median of 66%, which means half the states have participation rates of more than 66%. This can be seen as the 3rd quartile is consist of states with participation rates of 66% to 100% and the 4th quartile consist of states with all 100% participation rates.
#
# The ACT 2018 participation rates also follow a bimodal distribution with 2 peaks, the lower range of about 25% to 35% and a higher range of 90% to 100%. As seen from the histogram however, it can be seen that the peak in the lower range in 2018 is smaller that it was in 2017, however the mean and median had decreased slightly, this is because from the histogram it can be seen that there were more states that fell in the lower ranges of around 10% to 40$ participation rates, although more states still fall in the higher range of 90% to 100%, which explains why the mean and median are still relatively high.
#
# The spread of the participation rates of ACT 2018 is 93. This is similar to what we seen in 2017. As the spread is higher by 1 it explains why the standard deviation is also higher than 2017 at 34. The 2019 particiapation rates also spread very far from its mean, there are states with particiaption rates at the extreme ends.
#
# Therefore it can be seen that the participation rate for the ACT has decresed slightly from 2017 to 2018.

# %% [markdown]
# #### <u> Participation rates for SAT 2017 and 2018

# %% [markdown]
# For SAT 2017 particiaption rates, the mean of about 40% shows that most states have a lower participation rate. There are 25 out of the 51 states that have participation rates higher than the mean. Even though it is almost half the states, the mean is still quite low, and this could be explained that those states with participation rates that fall below the mean have an extremely low participation rate pulling the average mean of all states down as can be seen with the lowest participation rate at only 2% that can be seen in 3 states, North Dakota, Mississippi and Iowa. This is further emphasized with a median of only 38%, which means half the states have participation rates of lower than 38%. This can be seen as the 1st quartile consist of states with participation rates of 2% to 4% and the 2nd quartile consist of states with 4% to 38% participation rates.
#
# For SAT 2018 participation rates, it has a mean of 46% which also shows that more states have a lower participation rate. Its median is 52%, which means half the states have participation rates of lower than 52%. We can see that the mean and median for 2018 falls very closely to the halfway mark. There are 27 out of the 51 states that have participation rates higher than the mean. Even though more than half the states have participation rates higher than the mean, the mean is still quite low, and this could be explained that those states with participation rates that fall below the mean have an extremely low participation rate pulling the average mean of all states down as can be seen with the lowest participation rate at only 2% which can be seen in North Dakota.
#
# The SAT 2017 and 2018 distribution for participation rates are right skewed. There is 1 most prominent peak which falls within the smallest range of their min value to about 10% participation rate for both. This further explains the low mean and median. However for the 2018 participation rates, it can be seen on the graph that there are slightly more states that fall in the higher participation rates especially within the range of 90% to 100%. Although the 2018 still seems to still be skewed to the right, it can explain why the mean and median fall very closely to the middle of the range.
#
# The spread of the participation rates for SAT 2017 and 2018 is the same at 98. This is even wider than the spread of the ACT participation rates. This explains why the standard deviation is higher than those of the ACT, at 35 and 37 for 2017 and 2018 respectively. Even though the spread is the same, the standard deviation differs may be because in 2018, there are more states that have participation rates that fall even further from its mean, this can be seen in the histogram that there are more states that fall in the 90% to 100% participation rate as compared to 2017.
#
# Therefore it can be seen that in general, the particiaption rate for SAT although improved in 2018 from 2017, only did so very slightly.

# %% [markdown]
# *The ACT and SAT participation rates can therefore be said to have a negative correlation which was also shown in the line graphs which shows that as the participation rates for ACT increases, the participation rates for SAT decreases and vice versa.*

# %% [markdown]
# #### <u> Math Scores for ACT 2017 and 2018

# %%
combined_all[["act17_math","act18_math","sat17_math","sat18_math"]].describe()
# Out:
#        act17_math  act18_math  sat17_math  sat18_math
# count   51.000000   51.000000   51.000000   51.000000
# mean    21.182353   21.125490  556.882353  556.235294
# std      1.981989    2.035765   47.121395   47.772623
# min     18.000000   17.800000  468.000000  480.000000
# 25%     19.400000   19.400000  523.500000  522.500000
# 50%     20.900000   20.700000  548.000000  544.000000
# 75%     23.100000   23.150000  599.000000  593.500000
# max     25.300000   25.200000  651.000000  655.000000

# %%
combined_all.loc[combined_all['act17_math'] == 18]
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 28  Nevada                 100.0           16.3        18.0           18.1
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 28           18.2             17.8                  26.0        563
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 28         553  ...                 100.0             17.7           16.6
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 28        17.8           18.0           17.9                  23.0        574
#
#     sat18_math  sat18_total
# 28         566         1140
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['act18_math'] == 17.8]
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 28  Nevada                 100.0           16.3        18.0           18.1
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 28           18.2             17.8                  26.0        563
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 28         553  ...                 100.0             17.7           16.6
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 28        17.8           18.0           17.9                  23.0        574
#
#     sat18_math  sat18_total
# 28         566         1140
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['act17_math'] == 25.3]
# Out:
#             state  act17_par_percentage  act17_english  act17_math  \
# 21  Massachusetts                  29.0           25.4        25.3
#
#     act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 21           25.9           24.7             25.4                  76.0
#
#     sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 21        555         551  ...                  25.0             25.5
#
#     act18_english  act18_math  act18_reading  act18_science  \
# 21           25.5        25.2           25.9           24.7
#
#     sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 21                  80.0        562         563         1125
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['act18_math'] == 25.2]
# Out:
#             state  act17_par_percentage  act17_english  act17_math  \
# 21  Massachusetts                  29.0           25.4        25.3
#
#     act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 21           25.9           24.7             25.4                  76.0
#
#     sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 21        555         551  ...                  25.0             25.5
#
#     act18_english  act18_math  act18_reading  act18_science  \
# 21           25.5        25.2           25.9           24.7
#
#     sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 21                  80.0        562         563         1125
#
# [1 rows x 21 columns]

# %% [markdown]
# The mean of the 2017 and 2018 ACT Math scores for all states is about 21. Both have a median of about 21 as well. From the histogram, the mode score lies between 19 and 20. From these statistics, we could assume it follows a normal distribution. Although from the histogram, it does seem quite normal, however it is slightly right skewed for both years. The min score of about 18 in Nevada and and max score of 25 in Massachusetts for both makes the distribution spread small, therefore the standard deviation is small at about 2 for both years as well. This shows that most states have an average of 21 out of 36 for math or near it, meaning the math score for each state do not fall far from the mean. The reason why the statistics show these results most likely is due to the scaled scoring system which was incorporated to reduce the varying of scores. From the boxplot we can also tell that the scores between 2017 and 2018 did not differ much from each other.

# %% [markdown]
# #### <u> Math Scores for SAT 2017 and 2018

# %%
combined_all.loc[combined_all['sat17_math'] == 468]
# Out:
#                   state  act17_par_percentage  act17_english  act17_math  \
# 8  District of Columbia                  32.0           24.4        23.5
#
#    act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 8           24.9           23.5             24.2                 100.0
#
#    sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 8        482         468  ...                  32.0             23.6
#
#    act18_english  act18_math  act18_reading  act18_science  \
# 8           23.7        22.7           24.4           23.0
#
#    sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 8                  92.0        497         480          977
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['sat17_math'] == 651]
# Out:
#         state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 23  Minnesota                 100.0           20.4        21.5           21.8
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 23           21.6             21.5                   3.0        644
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 23         651  ...                  99.0             21.3           20.2
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 23        21.4           21.7           21.4                   4.0        643
#
#     sat18_math  sat18_total
# 23         655         1298
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['sat18_math'] == 480]
# Out:
#                   state  act17_par_percentage  act17_english  act17_math  \
# 8  District of Columbia                  32.0           24.4        23.5
#
#    act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 8           24.9           23.5             24.2                 100.0
#
#    sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 8        482         468  ...                  32.0             23.6
#
#    act18_english  act18_math  act18_reading  act18_science  \
# 8           23.7        22.7           24.4           23.0
#
#    sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 8                  92.0        497         480          977
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['sat18_math'] == 655]
# Out:
#         state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 23  Minnesota                 100.0           20.4        21.5           21.8
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 23           21.6             21.5                   3.0        644
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 23         651  ...                  99.0             21.3           20.2
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 23        21.4           21.7           21.4                   4.0        643
#
#     sat18_math  sat18_total
# 23         655         1298
#
# [1 rows x 21 columns]

# %% [markdown]
# The SAT scores are base on a wider score range of 200 to 800 individual sections, which is a much wider range than the ACT. Therefore the standard deviation may seem larger compared to the ACT. The mean for both 2017 and 2018 are at about 556 and from the histogram, we can see that in both years, most states score an average between 520 to 550, which is the mode, explaining why the mean was also around this range. The median is 548 and 544 for 2017 and 2018, which is very closely similar. From the graph the distribution does not seem to follow a normal distribution, instead the graph is skewed to the right for both years as from the graph we can see most of the states have an average score below the mean and median. The lowest average score of 468 in 2017 and 480 in 2018, both in the District of Columbia and max score of 651 in 2017 and 655 in 2018, both in Minnesota. From the boxplot we can also tell that the scores between 2017 and 2018 did not differ much from each other.

# %% [markdown]
# #### <u> Reading Scores for ACT 2017 and 2018

# %%
combined_all[["act17_reading","act18_reading","sat17_erw","sat18_erw"]].describe()
# Out:
#        act17_reading  act18_reading   sat17_erw   sat18_erw
# count      51.000000      51.000000   51.000000   51.000000
# mean       22.013725      22.015686  569.117647  563.686275
# std         2.067271       2.167245   45.666901   47.502627
# min        18.100000      18.000000  482.000000  480.000000
# 25%        20.450000      20.450000  533.500000  534.500000
# 50%        21.800000      21.600000  559.000000  552.000000
# 75%        24.150000      24.100000  613.000000  610.500000
# max        26.000000      26.100000  644.000000  643.000000

# %%
combined_all.loc[combined_all['act17_reading'] == 18.1]
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 28  Nevada                 100.0           16.3        18.0           18.1
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 28           18.2             17.8                  26.0        563
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 28         553  ...                 100.0             17.7           16.6
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 28        17.8           18.0           17.9                  23.0        574
#
#     sat18_math  sat18_total
# 28         566         1140
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['act18_reading'] == 18]
# Out:
#      state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 28  Nevada                 100.0           16.3        18.0           18.1
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 28           18.2             17.8                  26.0        563
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 28         553  ...                 100.0             17.7           16.6
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 28        17.8           18.0           17.9                  23.0        574
#
#     sat18_math  sat18_total
# 28         566         1140
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['act17_reading'] == 26]
# Out:
#             state  act17_par_percentage  act17_english  act17_math  \
# 29  New Hampshire                  18.0           25.4        25.1
#
#     act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 29           26.0           24.9             25.5                  96.0
#
#     sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 29        532         520  ...                  16.0             25.1
#
#     act18_english  act18_math  act18_reading  act18_science  \
# 29           25.1        24.7           25.6           24.4
#
#     sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 29                  96.0        535         528         1063
#
# [1 rows x 21 columns]

# %%
combined_all.loc[combined_all['act18_reading'] == 26.1]
# Out:
#          state  act17_par_percentage  act17_english  act17_math  \
# 6  Connecticut                  31.0           25.5        24.6
#
#    act17_reading  act17_science  act17_composite  sat17_par_percentage  \
# 6           25.6           24.6             25.2                 100.0
#
#    sat17_erw  sat17_math  ...  act18_par_percentage  act18_composite  \
# 6        530         512  ...                  26.0             25.6
#
#    act18_english  act18_math  act18_reading  act18_science  \
# 6           26.0        24.8           26.1           24.9
#
#    sat18_par_percentage  sat18_erw  sat18_math  sat18_total
# 6                 100.0        535         519         1053
#
# [1 rows x 21 columns]

# %% [markdown]
# The mean of the 2017 and 2018 ACT reading scores for all states is about 22. Both have a median of about 22 as well. From the histogram, we can see that most states have an average reading score in the range of 20 to 22. Statistically it should follow a normal distribution. However, from the histogram, both years, the distribution seems to be slightly right skewed. This may be because as seen from the graph, most states have an average score that falls below the mean and median.
#
# The min score of about 18 in Nevada for both years and and max score of 26 in 2017 and 26.1 in 2018 in New Hampshire and Conneticut respectively. The distribution spread is small, therefore the standard deviation is small at about 2 for both year. This shows that most states have an average of 21 out of 36 for math or near it, meaning the reading score for each state do not fall far from the mean. The reason why the statistics show these results most likely is due to the scaled scoring system which was incorporated to reduce the varying of scores. From the boxplot we can also tell that the scores between 2017 and 2018 did not differ much from each other.

# %% [markdown]
# #### <u>English-beased Reading and Writing Scores for SAT 2017 and 2018

# %% [markdown]
# The histogram shows that states average SAT ERW scores for both years fall either in the range about 530 to 540 or around the range of 630 to 640 which is the mode, which explains why the mean score is 569 and 563 for 2017 and 2018 respectively. The median is 559 and 552 for 2017 and 2018 respectively. From the histogram, the distribution seems to be more bimodal for both years, as we see 2 peaks which was mentioned earlier.
#
# The standard deviation for 2017 and 2018 is 45.7 and 47.5 respectively. This tells us that the spread is quite wide. as the deviation from the mean is quite high. This can be seen from the histogram as well as statistical description. The spread is 162 and 163 for the year 2017 and 2018 respecitvely. The reason why the range between the min and max score is high as compared to ACT is because of the score system, which is scaled on a larger range of 200 to 800.

# %% [markdown]
# #### <u>Participation rates and their scores for ACT and SAT

# %% [markdown]
# It can be seen from the scatter plots of the individual and total/composite scores compared to their participation rates, there is a negative correlation. As the participation rate increases, the scores of each test decreases. We should ask ourselves then how much effort should we put in to improve participation rates, and should we do that? Or, should we be looking into spending more budget and effort to help states with lower scores improve their scores.

# %% [markdown]
# ### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
target_0 = combined_all['act17_par_percentage']
target_1 = combined_all['act18_par_percentage']
target_2 = combined_all['sat17_par_percentage']
target_3 = combined_all['sat18_par_percentage']

sns.distplot(target_0).set(xlabel='Participation rate')
sns.distplot(target_1).set(xlabel='Participation rate')
sns.distplot(target_2).set(xlabel='Participation rate')
sns.distplot(target_3).set(xlabel='Participation rate')

plt.show()

# %%
target_0 = combined_all['act17_math']
target_1 = combined_all['act18_math']

sns.distplot(target_0)
sns.distplot(target_1)

plt.show()

# %%
target_2 = combined_all['sat17_math']
target_3 = combined_all['sat18_math']

sns.distplot(target_2)
sns.distplot(target_3)

plt.show()

# %%
target_0 = combined_all['act17_reading']
target_1 = combined_all['act18_reading']

sns.distplot(target_0)
sns.distplot(target_1)

plt.show()

# %%
target_2 = combined_all['sat17_erw']
target_3 = combined_all['sat18_erw']

sns.distplot(target_2)
sns.distplot(target_3)

plt.show()

# %% [markdown]
# According to CLT, the sample mean distribution is normal whether or not the population distribution is a normal distribution, with the samples being random and with at least a sample size of 30 or more and iterations of the samples should be high, meaning more sample means, more normal the distribution.
#
# In this case, we have a sample mean of 51, which are the 51 states, but we do not know the sample size of each mean. The assumption accoring to CLT does not hold true for math, reading and rates. Although the math and reading scores do seem quite normal, there are still a little skewness to it. As all the distributions do not truly follow a noraml distribution, this means that the data do not fall on similar values which means there may have very large varying values between each data and there may be many outliers.
#
# Math for both ACT and SAT have a distribution that is slightly skewed to the right, with a peak at about 21 for ACT and 525 for SAT, from what we have described above, which is the same or close to its mean of 21 and 556 respectively. This is the mean from a spread of betwwen 18 to 25 for ACT and 474 to 653 for SAT. Therefore it is normal that the graph is slightly skewed to the right. This means that the mode falls more towards the left of the graph and left of the mean and median, which means most states average score fall below the mean score of all the states.
#
# Reading scores for ACT is similar to that of the math scores as explained above. However, for SAT ERW scores, it follows a bimodal distribution, which means there are 2 peaks. We could also say there are 2 modes to the scores, which could mean that there there is a group of states that may have a higher average score and another group of states with lower average score.
#
# The particiaption rates for both ACT and SAT also follows a bimodal distribution with 2 peaks. Which could mean in there is a group of states that have a larger participation rates and another group of states where we see a low participation rate.
#
# Normal distribution will have the mean, median and mode being all equal at the center of the data set, therefore making it easier to use that value to more accurately infer the data and come up with findings. However, as none of our data follows a normal distribution, we cannot confidently use the data to make statistical inference. We may try to construct our confidence interval, using our sample statistic and attach a margin of error to it. We can then quantify how confident we are that the true population parameter is inside the interval.

# %% [markdown]
# ### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# We are trying to make statistical inference of the scores and participation rates of both the ACT and SAT. These are made by taking sample means from the population.
#
# The data is not very granular, information given was not detailed enough. For example, for the participation rate, how was this rate calculated, was it based on the population of the state or the population of only those who had signed up for the test and actually sat for the test. The data could have been more granular in showing details of the gender and ethnicity of the participant who took, this may show a trend in scores and participation rates as well as how we may want to target to improve participation in which states and which ethnicity or gender in certain states.
#
# The aggregation of the scores and particiapation rates may differ greatly as the population size of each state are of different size, whereas the scores are bases on a similar scale. This explains why the aggregated participation rates as well as the scores are varying alot, which causes a non normal distribution.
#
# In this case, because of lack of information together with the fact that sample distribution of each variable are not normally distributed, it does not make sense for use to use the data to make statistical inference. Although we can still make some recommendations and conclusions based on it. However, we may want to construct our confidence interval, which will attach a margin of error to our sample statistics. Meaning, that if our sample falls within that interval, we can then say that we are confident we can use this sample statistics to infer about our population. The confidence interval can be calculated base on this formula:  [Sample statistic] 𝑥¯⇒𝑥¯±±±[multiplier] ×[standard deviation of sampling distribution]

# %% [markdown]
# If we were to use the act17_reading sample statistic as example:
#
# 22.013725 ± 1.96(assuming I want to find a confidence interval of is 95%)*2.067271

# %%
Lower_int = 22.013725 - (1.96*2.067271)
round(Lower_int,2)
# Out:
# 17.96

# %%
Higher_int = 22.013725 + (1.96*2.067271)
round(Higher_int,2)
# Out:
# 26.07

# %% [markdown]
# However in this case, we do not know that the data given for each rate and score is the national population of the students who if of age for college admissions or calculated base on a sample of the population.
#
# If those aggregates in our data are the population mean and population rates, we can then use the example calculated above using the act17_reading sample to check if the population data falls between the lower and upper confidence bound of (17.96,26.07). Looking at the act17_reading data, the min value is 18 and the max value is 26. Therefore if the data provided is base on a population level, we can say that we are 95% confident that the true population of the ACT 2017 reading scores of between min value 18 and max value 26 falls within the 17.96 lower confidence bound and 26.07 upper confidence bound.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# The score range and scoring system between both test are vastly different, the ACT scores an average of each section on a scale of 1-36, while the SAT scores each section on a scale of 200 to 800, with a total score of anywhere from 400-1600 points. Therfore, even if you score high on the ACT math for example with a score of 30, but score low on the SAT math with a score of 300. In comparison just numerically and on the graph, it may seem that the SAT math has a higher score than the ACT math which could be seen as a better score, when in actuality, the ACT math score is the better score. Therefore, it is not appropriate to compare the scores between ACT and SAT as it would be difficult and almost impossible to infer which performed better just based on the data.

# %% [markdown]
# ### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# The alternative hyposthesis which is what I am trying to test and prove is that the participation rate for the SAT and ACT, one is always higher than the other. Meaning to say that population mean participation rate of SAT minus ACT ≠ 0.
# Whereas the null hypothesis will be that the population mean participation rate of SAT minus ACT = 0.
#
# In this case, it is impossible for us to do the experiment as we do not have details for the control group as we only have one type of data.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
combined_all.loc[combined_all['act17_par_percentage']>50].shape
# Out:
# (31, 21)

# %%
combined_all.loc[combined_all['act18_par_percentage']>50].shape
# Out:
# (28, 21)

# %%
combined_all.loc[combined_all['sat17_par_percentage']>50].shape
# Out:
# (22, 21)

# %%
combined_all.loc[combined_all['sat18_par_percentage']>50].shape
# Out:
# (26, 21)

# %% [markdown]
# Although most colleges/Universities in the US do not prefer one test over the other and accepts both but the states themselves do have preference. From the overview of the graphs and tables above, we can see in general that the participation rate for ACT as a whole for all the states in both years exceeds the participation rate of SAT. Which makes sense because it does not make sense to take both test, therefore if most people take the ACT, they therefore would not take the SAT. However, we would need to look deeper into why ACT seems to be the more preferred test.

# %% [markdown]
# <font size=2>
#
# "*Though not identical, the ACT and SAT are more closely related than ever before as a result of the SAT’s massive redesign in 2016. Now, both exams have the following features*:
#
# *Contain similar sections (Reading, Math, etc.) in a predetermined order, with each section appearing just once
# Offer an optional essay section whose score does not count toward your total score
# Use rights-only scoring, meaning you will not be penalized for incorrect answers
# Contain entirely passage-based Reading and English/Writing questions (called English on the ACT and Writing and Language, or Writing, on the SAT)*
#
# *Despite all these similarities, there are still many ways in which the ACT and SAT differ from each other. For one, the SAT is overall slightly longer than the ACT. What's more, the number of questions and time limits are different for corresponding sections.*
#
# *ACT has a full section on Science whereas the SAT does test on science topics but do not have a seperate section dedicated to science. For math sections, the ACT does not allow calculator whereas the SAT has a section for math which allows a calculator. The ACT test on some topics of math that SAT does not for example, graphs and matrices. The importance of your math section to your total score. For ACT it acounts for 1 quarter of your total score whereas in SAT it accounts for half of it. There are many other factors that could make a person choose one test over the other."*
# Quoted from: [Prepscholar](#Sources)

# %% [markdown]
# These all could be reasons why the ACT seems to be the preferred exam over SAT in most states.
#
# However, I believe that the biggest factor that affects the participation rates are the state policies and requirements. Some states offer the tests for free, depending on the state it can be either of the test or both. Some states make it a requirement to take the test when they are juniors, depending on the state it can be either of the test, or require only the SAT or only the ACT. We will look at some of these effects below.

# %%
combined_all.loc[combined_all['state']== "Colorado"]
# Out:
#       state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 5  Colorado                 100.0           20.1        20.3           21.2
#
#    act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 5           20.9             20.8                  11.0        606
#
#    sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 5         595  ...                  30.0             23.9           23.9
#
#    act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 5        23.2           24.4           23.5                 100.0        519
#
#    sat18_math  sat18_total
# 5         506         1025
#
# [1 rows x 21 columns]

# %% [markdown]
# "*When statewide testing started, Colorado and Illinois decided to partner with ACT, Inc., to use the ACT as the assessment for 11th graders. This plan was meant to eliminate an extra test for students who were already planning to apply to college while also encouraging those who weren't planning for college to consider it. Over the next decade and a half, the two states became 20, and the ACT replaced the SAT as the most popular college admissions test in the US.*"
#
# This explains why the ACT participation rates as a whole over all the 51 states are obviously higher than the SAT participation rates.
#
# "*However, the redesigned SAT (released in 2016) seems to be shifting the momentum. One of the primary goals of the overhaul was to align the SAT with Common Core standards, making it far more appealing as an assessment test than the older version of the test.*"
#
# This could explain the shift of Colorado's participation rate of 100% from the ACT to SAT in 2018. The shift in participation could also be because of the mandatory requirement for all students from public schools in Colorado to take the SAT for free.
#
# Quoted from: [Prepscholar, which states require the test](#Sources)

# %%
combined_all.loc[combined_all['state']== "Delaware"]
# Out:
#       state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 7  Delaware                  18.0           24.1        23.4           24.8
#
#    act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 7           23.6             24.1                 100.0        503
#
#    sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 7         492  ...                  17.0             23.2           23.7
#
#    act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 7        23.1           24.5           23.4                 100.0        505
#
#    sat18_math  sat18_total
# 7         492          998
#
# [1 rows x 21 columns]

# %% [markdown]
# Accoring to the source: [Prepscholar, which states require the test](#Sources),  it stated that "*In 2016, the SAT replaced Delaware's Smarter Assessment state test for 11th graders.*"
#
# This shows that when states make the SAT exam a mandatory requirement and provided for free to students, the participation rate improves drastically.

# %%
combined_all.loc[combined_all['state']== "Tennessee"]
# Out:
#         state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 42  Tennessee                 100.0           19.5        19.2           20.1
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 42           19.9             19.8                   5.0        623
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 42         604  ...                 100.0             19.6           19.4
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 42        19.1           19.9           19.6                   6.0        624
#
#     sat18_math  sat18_total
# 42         607         1231
#
# [1 rows x 21 columns]

# %% [markdown]
# Accoring to the source: [Collegeraptor, states act sat given free](#Sources), it stated that "*In the states of Arizona, Minnesota, Tennessee, Florida, Texas, and Maryland, a few schools or districts can administer the SAT exam to their students. This may be optional or a mandatory requirement.*"
#
# From the data, we see that the participation rates for SAT is extremely low in both years. It could be that schools or districts do not practiice administering the SAT exam to their students which makes neither of the exams to be free.
#
# The state of Tennessee requirements are that students must take either the SAT or ACT. From the data, we can see that the preference of the students in Tennessee is the ACT test. This is unbiased preference as although it is a requirement to take either of the tests, the state does not offer them for free. Therefore we could understand unless SAT is required in by the state, it would seem that the preferred choice would be the ACT.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
combined_all[['state','sat18_par_percentage']].sort_values(by='sat18_par_percentage',ascending=True).head(10)
# Out:
#            state  sat18_par_percentage
# 34  North Dakota                   2.0
# 50       Wyoming                   3.0
# 41  South Dakota                   3.0
# 27      Nebraska                   3.0
# 49     Wisconsin                   3.0
# 24   Mississippi                   3.0
# 15          Iowa                   3.0
# 44          Utah                   4.0
# 23     Minnesota                   4.0
# 18     Louisiana                   4.0

# %%
combined_all.loc[combined_all['state']=='Nebraska']
# Out:
#        state  act17_par_percentage  act17_english  act17_math  act17_reading  \
# 27  Nebraska                  84.0           20.9        20.9           21.9
#
#     act17_science  act17_composite  sat17_par_percentage  sat17_erw  \
# 27           21.5             21.4                   3.0        629
#
#     sat17_math  ...  act18_par_percentage  act18_composite  act18_english  \
# 27         625  ...                 100.0             20.1           19.4
#
#     act18_math  act18_reading  act18_science  sat18_par_percentage  sat18_erw  \
# 27        19.8           20.4           20.1                   3.0        629
#
#     sat18_math  sat18_total
# 27         623         1252
#
# [1 rows x 21 columns]

# %% [markdown]
# We are unable to use the ACT and SAT scores for proper comparison as they follow a different scoring system which explains why the ACT and SAT scores have a negative correlation. The ACT follows a scaled scoring system with a small range of 1-36, whereas the SAT follows a wider ranged scaled scoring system of 200-800 per section which would total to 400-1600 as a total score for the exam. This may give the illusion to the public that it is easier to score better for ACT as the scores do not vary as much, especially when you see the statistical information. For example, as seen above, the composite score for the ACT in 2017 has a mean of 21.5, standard deviation of 2, minimum score fo 17.8 and maximum score of 25.5, whereas, the SAT total score in 2017 has a mean of 1126, standard deviation of 92, a minimum score of 950 and maximum score of 1295. With such numbers, it may seem that the risk of scoring lower in SAT is higher as it varies from the mean greater than the ACT scores. We may then want to consider changing the SAT scoring system to ensure scores from varying too much.
#
# We have also found out that all the sample data do not follow a normal distribution. It is normal to see the graph skewed to one side for scores as there is always a chance that most of the students will fall in a particular range of scores, depending where that range is, that will be the mode which is also the peak of the distribution. As all the sample data do not follow a normal distribution, a confidence interval testing should be done.
#
# From 2017 to 2018, we have seen a slight increase in participation rates for SAT, although statistically students are showing more preference to the ACT exam still. After the introduction of the new SAT format in 2016, there is definitely an increase in participation rate of the SAT exam, this may be the reason why the state of Colorado and Illinois showed a change from an extremely high ACT and low SAT participation rate to the opposite, with a low ACT and high SAT participation rate. We should then consider if revising the SAT format to maybe include a science section which is lacking in the SAT in comparison to the ACT. We could also revise the number of sections in the SAT by splitting them up into more sections, which will lessen the importance of each section on the total score. This may be one of the reason why students would choose the ACT, because if a section was done badly, it would pull down the total score of the SAT more than it would for the ACT.
#
# From my findings, we can see that when the state made the SAT exam free and a mandatory requirement, the participation rate was extremely high. However, states where both ACT or SAT is acceptable but the state does not provide either of them to be taken for free, the participation rate is high for ACT and not for SAT. From this, we can say that students in most states would prefer taking the ACT rather than the SAT, and this may also be the case because as of now, there are more states providing the ACT exam for free rather than the SAT, which may be the reason why the ACT participation rates are still higher than SAT.
#
# As we have seen a trend whereby states with high ACT participation would usually have a low SAT participation, this is because both exams are acceptable my almost all Colleges/Universities. Therefore the deciding or we can say the sway factor to either exam could be due to both the exam format and the states policies and requirements in regards to the exams. If we look at Nebraska, which has and increasing trend in ACT participation rate from 84% in 2017 to 100% in 2018, whereas the SAT participation rate was stagnant at 3%. Nebraska does not have any mandatory requirements for either exams and does not provide any of the exams for free to students.
#
# We may want to consider revising the exam format so that it may appeal to students who prefer the ACT to SAT now. For example instead of only 2 sections, to split these sections into more sections to reduce the importance of each section score on its total score, this may help to increase nation wide participation rate. However, from my findings, state policies and requirements on standardized tests. To dramatically shift the particiapation rates in favor of SAT, we need to look into specific states policies on standardized tests. In this case, looking into Nebraska, we may want to discuss with and convince the state of Nebraska to make the SAT exam compulsory for all junior students or provide the exam for free or both.

# %% [markdown]
# ## Sources

# %% [markdown]
# Author’s name, ***Hannah Muniz***. Title of Document, ***SACT vs SAT: 11 Key Differences to Help You Pick the Right Test***. Title of Website, ***PrepScholar New SAT***. Sponsor of Website, ***PrepScholar***. Date of Document, ***August 16 2020***. Date of Access, November 7, 2020. URL, https://blog.prepscholar.com/act-vs-sat
#
# Author’s name, ***Allison Wignall***. Title of Document, ***Preference of the ACT or SAT by State (Infographic)***. Title of Website, ***College Raptor***. Sponsor of Website, ***NCES, ACT, College Board***. Date of Document, ***August 19 2020***. Date of Access, November 7, 2020. URL, https://www.collegeraptor.com/getting-in/articles/act-sat/preference-act-sat-state-infographic/
#
# Author’s name, ***Alex Heimbach***. Title of Document, ***SAT / ACT Prep Online Guides and Tips
# Which States Require the SAT? Complete List***. Title of Website, ***PrepScholar New SAT***. Sponsor of Website, ***PrepScholar***. Date of Document, ***October 11 2020***. Date of Access, November 7, 2020. URL, https://blog.prepscholar.com/which-states-require-the-sat
#
# Author’s name, ***Alex Heimbach***. Title of Document, ***SAT / ACT Prep Online Guides and Tips
# Which States Require the ACT? Full List and Advice***. Title of Website, ***PrepScholar New SAT***. Sponsor of Website, ***PrepScholar***. Date of Document, ***August 3 2020***. Date of Access, November 7, 2020. URL, https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
#
# Author’s name, ***RACHEL KAPELKE-DALE***. Title of Document, ***States that Require the ACT or SAT***. Title of Website, ***Magoosh***. Sponsor of Website, ***EducationWeek***. Date of Document, ***October 24 2018***. Date of Access, November 7, 2020. URL, https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/
#
# Author’s name, ***College Raptor Staff***. Title of Document, ***States That Provide A Free ACT/ SAT Test***. Title of Website, ***College Raptor***. Sponsor of Website, ***College Raptor***. Date of Document, ***October 22 2020***. Date of Access, November 7, 2020. URL, https://www.collegeraptor.com/getting-in/articles/act-sat/states-act-sat-given-free/
